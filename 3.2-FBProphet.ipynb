# %% [markdown]
# # Capstone: Bitcoin: Time Series Forecasting Using Machine Learning

# %% [markdown]
# ## 3.2 Modeling - Facebook Prophet
# ---

# %% [markdown]
# Facebook Prophet is used for forecasting time series data and it uses an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects.
#
# It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.
#
# Let's see if it does better than the SARIMA and SARIMAX models in dealing with seasonality and volatility.

# %% [markdown]
# ## Imports
# ---

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline
from matplotlib.pylab import rcParams
plt.style.use('ggplot')

from sklearn.metrics import mean_squared_error, mean_absolute_error

import _pickle as pickle

from fbprophet import Prophet

# %% [markdown]
# ### Loading in the Data

# %%
with open("curr_bitcoin.pickle",'rb') as fp:
    ts = pickle.load(fp)

# %% [markdown]
# ### Formatting the data for Facebook Prophet

# %%
# Resetting the index back so Dates are no longer indexed
ts.reset_index(inplace=True)

# Renaming the columns for use in FB prophet
ts.rename(columns={'Date': 'ds', 'Close': 'y'}, inplace=True)
ts.drop(columns=['High', 'Low', 'Open'], inplace=True)
ts.tail()
# Out:
#              ds             y
# 3772 2020-11-13  16311.513323
# 3773 2020-11-14  16075.452734
# 3774 2020-11-15  15962.098952
# 3775 2020-11-16  16709.612284
# 3776 2020-11-17  17667.381593

# %%
ts.shape
# Out:
# (3777, 2)

# %% [markdown]
# #### Plotting

# %%
# Plotting the price 
pd.plotting.register_matplotlib_converters()

ax = ts.set_index('ds').plot(figsize=(16,8))
ax.set_ylabel('Bitcoin Price')
ax.set_xlabel('Date')

plt.show()

# %% [markdown]
# ### Modeling

# %%
# Setting up modeling
# Added seasonality layers for monthly and halving periods

# %%
# Fitting and training
mod = Prophet(interval_width=0.95, yearly_seasonality=True, 
               weekly_seasonality=True)
mod.add_seasonality(name='monthly', period=30.5, fourier_order=7, 
                    prior_scale=1)
mod.add_seasonality(name='halving', period=1460, fourier_order=40,
                   prior_scale=1)
mod.fit(ts)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast = mod.predict(ts)
forecast.tail()
# Out:
#              ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 3772 2020-11-13  13515.920876  11773.710905  14837.985039  13515.920876
# 3773 2020-11-14  13528.688261  11715.293068  14731.543881  13528.688261
# 3774 2020-11-15  13541.455646  11529.462082  14599.498642  13541.455646
# 3775 2020-11-16  13554.223031  11468.995718  14480.535545  13554.223031
# 3776 2020-11-17  13566.990416  11441.686848  14306.985485  13566.990416
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 3772  13515.920876     -216.840532           -216.840532
# 3773  13528.688261     -338.267015           -338.267015
# 3774  13541.455646     -485.283575           -485.283575
# 3775  13554.223031     -598.758154           -598.758154
# 3776  13566.990416     -726.261905           -726.261905
#
#       additive_terms_upper       halving  ...    weekly  weekly_lower  \
# 3772           -216.840532  34457.211962  ... -0.732817     -0.732817
# 3773           -338.267015  35004.074208  ...  4.665189      4.665189
# 3774           -485.283575  35479.792897  ... -4.941645     -4.941645
# 3775           -598.758154  35882.840541  ...  8.217778      8.217778
# 3776           -726.261905  36212.807774  ...  4.178629      4.178629
#
#       weekly_upper        yearly  yearly_lower  yearly_upper  \
# 3772     -0.732817 -34675.050351 -34675.050351 -34675.050351
# 3773      4.665189 -35339.314175 -35339.314175 -35339.314175
# 3774     -4.941645 -35943.170901 -35943.170901 -35943.170901
# 3775      8.217778 -36483.117510 -36483.117510 -36483.117510
# 3776      4.178629 -36956.633099 -36956.633099 -36956.633099
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 3772                   0.0                         0.0
# 3773                   0.0                         0.0
# 3774                   0.0                         0.0
# 3775                   0.0                         0.0
# 3776                   0.0                         0.0
#
#       multiplicative_terms_upper          yhat
# 3772                         0.0  13299.080344
# 3773                         0.0  13190.421246
# 3774                         0.0  13056.172071
# 3775                         0.0  12955.464877
# 3776                         0.0  12840.728511
#
# [5 rows x 25 columns]

# %%
test_mae = mean_absolute_error(ts['y'], forecast['yhat'])
test_rmse = np.sqrt(mean_squared_error(ts['y'], forecast['yhat']))

print(f" Prophet's MAE : {test_mae}")
print(f"Prophet's RMSE : {test_rmse}")
# Out:
#  Prophet's MAE : 511.61342022082806
# Prophet's RMSE : 767.9404684855838

# %% [markdown]
# ### Plotting Values
# * Blue line = forecasted values
# * Black dots = observed values
# * Uncertainty intervals = blue shaded region

# %%
mod.plot(forecast, uncertainty=True)
plt.title('Facebook Prophet Forecast and Fitting')
plt.savefig('fb_fc_fit.png')
plt.show()

# %% [markdown]
# #### Creating future dates to forecast

# %% [markdown]
# #### Forecasting future values

# %%
# Setting up predictions to be made
future = mod.make_future_dataframe(periods=364, freq='D')
print(future.shape)
future.tail()
# Out:
# (4141, 1)
#              ds
# 4136 2021-11-12
# 4137 2021-11-13
# 4138 2021-11-14
# 4139 2021-11-15
# 4140 2021-11-16

# %%
# Making predictions
forecast = mod.predict(future)
print(forecast.shape)
forecast.head()
# Out:
# (4141, 25)
#           ds       trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2010-07-17 -659.314678 -1229.244482  1804.437116  -659.314678  -659.314678
# 1 2010-07-18 -659.054671 -1199.358797  1646.000957  -659.054671  -659.054671
# 2 2010-07-19 -658.794663 -1106.771924  1900.764228  -658.794663  -658.794663
# 3 2010-07-20 -658.534655 -1038.706776  1969.007688  -658.534655  -658.534655
# 4 2010-07-21 -658.274647 -1075.990576  1927.388958  -658.274647  -658.274647
#
#    additive_terms  additive_terms_lower  additive_terms_upper       halving  \
# 0      978.694715            978.694715            978.694715 -29908.293823
# 1      986.416157            986.416157            986.416157 -29393.794681
# 2     1027.118581           1027.118581           1027.118581 -28872.862394
# 3     1054.876943           1054.876943           1054.876943 -28344.472512
# 4     1074.404072           1074.404072           1074.404072 -27807.637853
#
#    ...    weekly  weekly_lower  weekly_upper        yearly  yearly_lower  \
# 0  ...  4.665189      4.665189      4.665189  30908.391966  30908.391966
# 1  ... -4.941645     -4.941645     -4.941645  30430.033708  30430.033708
# 2  ...  8.217778      8.217778      8.217778  29940.680529  29940.680529
# 3  ...  4.178629      4.178629      4.178629  29438.614589  29438.614589
# 4  ... -2.899523     -2.899523     -2.899523  28922.268995  28922.268995
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0  30908.391966                   0.0                         0.0
# 1  30430.033708                   0.0                         0.0
# 2  29940.680529                   0.0                         0.0
# 3  29438.614589                   0.0                         0.0
# 4  28922.268995                   0.0                         0.0
#
#    multiplicative_terms_upper        yhat
# 0                         0.0  319.380037
# 1                         0.0  327.361486
# 2                         0.0  368.323919
# 3                         0.0  396.342288
# 4                         0.0  416.129425
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Plotting Values
# * Blue line = forecasted values
# * Black dots = observed values
# * Uncertainty intervals = blue shaded region

# %%
mod.plot(forecast, uncertainty=True)
plt.title('Facebook Prophet Forecast and Fitting')
plt.savefig('fb_fc_fit.png')
plt.show()

# %% [markdown]
# #### Graph above zoomed in

# %%
mod.plot(forecast, uncertainty=True)

plt.xlim(['2020-01-01', '2021-03-01'])
plt.ylim([1000, 20000])
plt.savefig('fb_zoom.png')
plt.show()

# %% [markdown]
# #### Plotted components of the forecasts

# %%
mod.plot_components(forecast)
plt.show()

# %% [markdown]
# #### Plotted changepoints

# %%
from fbprophet.plot import add_changepoints_to_plot

# %%
fig = mod.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), mod, forecast)

# %% [markdown]
# ## Adding exogenous variables

# %% [markdown]
# ### Loading in the Data

# %%
with open("exog_bitcoin.pickle",'rb') as fp:
    ts = pickle.load(fp)

# %%
ts.tail()
# Out:
#                      market_mvrv_more_155         ma128          ma14  \
# t
# 2020-11-18 02:00:00              1.800986  7.724089e+22  7.259935e+22
# 2020-11-18 03:00:00              1.800986  7.724089e+22  7.259935e+22
# 2020-11-18 04:00:00              1.800986  7.724089e+22  7.259935e+22
# 2020-11-18 21:40:00              1.800986  7.724089e+22  7.259935e+22
# 2020-11-18 21:50:00              1.800986  7.724089e+22  7.259935e+22
#
#                             ma200          ma25          ma40          ma60  \
# t
# 2020-11-18 02:00:00  7.321730e+22  7.789492e+22  8.029164e+22  4.058201e+22
# 2020-11-18 03:00:00  7.321730e+22  7.789492e+22  8.029164e+22  4.058201e+22
# 2020-11-18 04:00:00  7.321730e+22  7.789492e+22  8.029164e+22  4.058201e+22
# 2020-11-18 21:40:00  7.321730e+22  7.789492e+22  8.029164e+22  4.058201e+22
# 2020-11-18 21:50:00  7.321730e+22  7.789492e+22  8.029164e+22  4.058201e+22
#
#                               ma9          ma90  \
# t
# 2020-11-18 02:00:00  7.287512e+22  7.892102e+22
# 2020-11-18 03:00:00  7.287512e+22  7.892102e+22
# 2020-11-18 04:00:00  7.287512e+22  7.892102e+22
# 2020-11-18 21:40:00  7.287512e+22  7.892102e+22
# 2020-11-18 21:50:00  7.287512e+22  7.892102e+22
#
#                      addresses_accumulation_balance  ...  \
# t                                                    ...
# 2020-11-18 02:00:00                    2.361896e+06  ...
# 2020-11-18 03:00:00                    2.361896e+06  ...
# 2020-11-18 04:00:00                    2.361896e+06  ...
# 2020-11-18 21:40:00                    2.361896e+06  ...
# 2020-11-18 21:50:00                    2.361896e+06  ...
#
#                      entities_active_count  \
# t
# 2020-11-18 02:00:00               178521.0
# 2020-11-18 03:00:00               178521.0
# 2020-11-18 04:00:00               178521.0
# 2020-11-18 21:40:00               178521.0
# 2020-11-18 21:50:00               178521.0
#
#                      indicators_net_unrealized_profit_loss  \
# t
# 2020-11-18 02:00:00                                0.60368
# 2020-11-18 03:00:00                                0.60368
# 2020-11-18 04:00:00                                0.60368
# 2020-11-18 21:40:00                                0.60368
# 2020-11-18 21:50:00                                0.60368
#
#                      addresses_receiving_from_exchanges_count  supply_current  \
# t
# 2020-11-18 02:00:00                                   17005.0     18546393.75
# 2020-11-18 03:00:00                                   17005.0     18546393.75
# 2020-11-18 04:00:00                                   17005.0     18546393.75
# 2020-11-18 21:40:00                                   17005.0     18546393.75
# 2020-11-18 21:50:00                                   17005.0     18546393.75
#
#                      transactions_transfers_to_exchanges_count  \
# t
# 2020-11-18 02:00:00                                    44501.0
# 2020-11-18 03:00:00                                    44501.0
# 2020-11-18 04:00:00                                    44501.0
# 2020-11-18 21:40:00                                    44501.0
# 2020-11-18 21:50:00                                    44501.0
#
#                      indicators_sopr_less_155  month  week  day  day_of_week
# t
# 2020-11-18 02:00:00                  0.997702     11    47   18            2
# 2020-11-18 03:00:00                  0.997702     11    47   18            2
# 2020-11-18 04:00:00                  0.997702     11    47   18            2
# 2020-11-18 21:40:00                  0.997702     11    47   18            2
# 2020-11-18 21:50:00                  0.997702     11    47   18            2
#
# [5 rows x 108 columns]

# %%
ts.reset_index(inplace=True)

# %%
# Renaming the columns for use in FB prophet
ts.rename(columns={'t': 'ds', 'Close': 'y'}, inplace=True)
ts.drop(columns=['High', 'Low', 'Open'], inplace=True)

# %%
# Resetting the index back so Dates are no longer indexed
ts.reset_index(drop=True, inplace=True)
ts.head()
# Out:
#           ds  market_mvrv_more_155         ma128          ma14         ma200  \
# 0 2010-01-01              4.849526  4.313379e+09  4.463299e+09  4.306751e+09
# 1 2010-01-02              4.849526  4.319516e+09  4.519409e+09  4.310678e+09
# 2 2010-01-03              4.849526  4.325653e+09  4.575520e+09  4.314606e+09
# 3 2010-01-04              4.849526  4.331790e+09  4.631631e+09  4.318534e+09
# 4 2010-01-05              4.849526  4.337927e+09  4.687741e+09  4.322461e+09
#
#            ma25          ma40          ma60           ma9          ma90  ...  \
# 0  4.389233e+09  4.353883e+09  2.169753e+09  4.556816e+09  4.321152e+09  ...
# 1  4.420655e+09  4.373522e+09  2.176318e+09  4.644100e+09  4.329881e+09  ...
# 2  4.452077e+09  4.393161e+09  2.182929e+09  4.731383e+09  4.338609e+09  ...
# 3  4.483499e+09  4.412799e+09  2.189539e+09  4.818666e+09  4.347337e+09  ...
# 4  4.514921e+09  4.432438e+09  2.196157e+09  4.905949e+09  4.356065e+09  ...
#
#    entities_active_count  indicators_net_unrealized_profit_loss  \
# 0                    4.0                               0.421756
# 1                    0.0                               0.421756
# 2                    0.0                               0.421756
# 3                    5.0                               0.421756
# 4                    0.0                               0.421756
#
#    addresses_receiving_from_exchanges_count  supply_current  \
# 0                                       0.0       1631150.0
# 1                                       0.0       1637400.0
# 2                                       0.0       1646700.0
# 3                                       0.0       1655750.0
# 4                                       0.0       1665650.0
#
#    transactions_transfers_to_exchanges_count  indicators_sopr_less_155  month  \
# 0                                        1.0                  1.325994      1
# 1                                        1.0                  1.325994      1
# 2                                        1.0                  1.325994      1
# 3                                        1.0                  1.325994      1
# 4                                        1.0                  1.325994      1
#
#    week  day  day_of_week
# 0    53    1            4
# 1    53    2            5
# 2    53    3            6
# 3     1    4            0
# 4     1    5            1
#
# [5 rows x 106 columns]

# %%
exogenous_features = [i for i in ts.columns if i not in 'ydsCloseHighOpenLow']

# %%
split_date = "2020-01-01"
train_filt = ts['ds'] < split_date
test_filt = ts['ds'] >= split_date

train = ts[train_filt]
test = ts[test_filt]

# %%
print("train data shape :", train.shape)
print("test data shape :", test.shape)
# Out:
# train data shape : (86549, 106)
# test data shape : (8057, 106)

# %%
model = Prophet()
for feature in exogenous_features:
    model.add_regressor(feature)

model.fit(train[["ds", "y"] + exogenous_features])

forecast = model.predict(test[["ds"] + exogenous_features])

# %%
forecast.tail()

# %% [markdown]
# ### Plotting Values
# * Blue line = forecasted values
# * Black dots = observed values
# * Uncertainty intervals = blue shaded region

# %%
# Plot Our Predictions
model.plot(forecast, uncertainty=True)
plt.title('Facebook Prophet Forecast and Fitting');

# %% [markdown]
# #### Graph above zoomed in

# %%
model.plot(forecast, uncertainty=True)

plt.xlim(['2020-01-01', '2021-03-01'])
plt.ylim([1000, 20000])
plt.savefig('fb_zoom.png')
plt.show()

# %%
mod.plot(forecast, uncertainty=True)

plt.xlim(['2020-01-01', '2021-03-01'])
plt.ylim([1000, 20000])
plt.savefig('fb_zoom.png')
plt.show()

# %% [markdown]
# #### Plotted components of the forecasts

# %%
model.plot_components(forecast)
plt.show()

# %% [markdown]
# #### Plotted changepoints

# %%
from fbprophet.plot import add_changepoints_to_plot

# %%
fig = mod.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), mod, forecast,threshold=1.5)

# %% [markdown]
# ### Update Validation Data Pickle

# %%
with open("valid_ARIMAX_bitcoin.pickle",'rb') as fp:
    test = pickle.load(fp)

# %%
test["Forecast_Prophet"] = forecast.yhat.values

# %%
with open("valid_FBProphet_bitcoin.pickle", 'wb') as fp:
    pickle.dump(test, fp)

# %% [markdown]
# ### Plotting our predictions against the test data

# %%
test[["y", "Forecast_Prophet"]].plot(figsize=(14, 7));

# %% [markdown]
# ### MAE and RMSE

# %%
test_mae = mean_absolute_error(test['y'], test['Forecast_Prophet'])
test_rmse = np.sqrt(mean_squared_error(test['y'], test['Forecast_Prophet']))

print(f" Prophet's MAE : {test_mae}")
print(f"Prophet's RMSE : {test_rmse}")

# %% [markdown]
# Our best results so far!

# %%
#Keeping only relevant columns
forecast_df = forecast[['ds','yhat','yhat_lower','yhat_upper' ]]
forecast_df

# Plotting the predicted values -> yhat
forecast_df.set_index('ds')['yhat'].plot()

# %%
# Plotting both actual and the predicted values -> y and yhat
pd.concat([ts.set_index('ds')['y'],forecast_df.set_index('ds')['yhat']], axis=1).plot()  

test_fb = forecast_df[forecast_df['ds']>= "2020-01-02"]
df_concat = test_fb.merge(test,how='inner',on="ds")
df_concat.plot(x="ds", y=["y", "yhat"])

# %%
# # Checking Deltas
deltas = model.params['delta'].mean(0)
deltas

# Plotting changepoints
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(range(len(deltas)), deltas)
ax.grid(True, which='major', c='red', ls='-', lw=1, alpha=0.2)
ax.set_ylabel('Rate change')
ax.set_xlabel('changepoint')
fig.tight_layout()

# Checking model changepoints

list(zip(range(1,26),model.changepoints, deltas))

# %% [markdown]
# Relevant changepoint dates from the data.

# %%
# # Checking Deltas
deltas = mod.params['delta'].mean(0)
deltas

# Plotting changepoints
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(range(len(deltas)), deltas)
ax.grid(True, which='major', c='red', ls='-', lw=1, alpha=0.2)
ax.set_ylabel('Rate change')
ax.set_xlabel('changepoint')
fig.tight_layout()

# Checking model changepoints

list(zip(range(1,26),model.changepoints, deltas))

# %% [markdown]
# #### Creating future dates to forecast

# %% [markdown]
# #### Forecasting future values

# %%
model = Prophet()
for feature in exogenous_features:
    model.add_regressor(feature)

model.fit(ts[["ds", "y"] + exogenous_features])

forecast = model.predict(ts[["ds"] + exogenous_features])
forecast.head()

# %%
# Setting up predictions to be made
future = model.make_future_dataframe(periods=364, freq='D')
print(future.shape)
future.tail()

# %%
future[exogenous_features] = 0

# %%
# Making predictions
forecast = model.predict(future[['ds'] + exogenous_features])
print(forecast.shape)
forecast.head()

# %%
mod.plot(forecast, uncertainty=True)
plt.title('Facebook Prophet Forecast and Fitting')
plt.savefig('fb_fc_fit.png')
plt.show()

# %% [markdown]
# ### Update Validation Data Pickle

# %%
with open("valid_ARIMAX_bitcoin.pickle",'rb') as fp:
    test = pickle.load(fp)

# %%
test["Forecast_Prophet"] = forecast.yhat.values

# %%
with open("valid_FBProphet_bitcoin.pickle", 'wb') as fp:
    pickle.dump(test, fp)

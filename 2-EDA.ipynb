# %%
import pandas as pd

# %%
df = pd.read_csv('data/combined.csv')

# %%
df.head()
# Out:
#             t  market_mvrv_more_155  addresses_accumulation_balance  \
# 0  2010-01-01                   NaN                        70018.15
# 1  2010-01-02                   NaN                        70018.15
# 2  2010-01-03                   NaN                        70018.15
# 3  2010-01-04                   NaN                        90722.50
# 4  2010-01-05                   NaN                        90722.50
#
#    addresses_new_non_zero_count  indicators_sopr_account_based  \
# 0                         134.0                            NaN
# 1                         126.0                            NaN
# 2                         186.0                            NaN
# 3                         183.0                            NaN
# 4                         198.0                            NaN
#
#    indicators_sopr_adjusted  transactions_rate  market_mvrv  \
# 0                       NaN           0.000023          NaN
# ...
